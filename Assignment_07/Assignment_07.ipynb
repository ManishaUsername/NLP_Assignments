# %% [markdown]
# Assignment 07: Develop a text preprocessing and analysis application using NLTK for tokenization, POS
# tagging, and basic NLP tasks.

# %% [markdown]
# Step 1: Install Required Libraries

# %%
pip install nltk

# %% [markdown]
# Step 2: Import Libraries & Download NLTK Resources

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')

nltk.download('punkt')        # Tokenizer
nltk.download('stopwords')    # Stopwords
nltk.download('averaged_perceptron_tagger')  # POS Tagger
nltk.download('wordnet')      # Lemmatization
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# Step 3: Input Text

# %%
text = "Natural Language Processing enables computers to understand human language."

# %% [markdown]
# Step 4: Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize

text = "Natural Language Processing enables computers to understand human language."
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Natural Language Processing enables computers to understand human language.']

# %% [markdown]
# Step 5: Word Tokenization

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(text)
print(words)
# Out:
# ['Natural', 'Language', 'Processing', 'enables', 'computers', 'to', 'understand', 'human', 'language', '.']

# %% [markdown]
# Step 6: Remove Stopwords

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]

print(filtered_words)
# Out:
# ['Natural', 'Language', 'Processing', 'enables', 'computers', 'understand', 'human', 'language', '.']

# %% [markdown]
# Step 7: Stemming

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_words]

print(stemmed_words)
# Out:
# ['natur', 'languag', 'process', 'enabl', 'comput', 'understand', 'human', 'languag', '.']

# %% [markdown]
# Step 8: Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

print(lemmatized_words)
# Out:
# ['Natural', 'Language', 'Processing', 'enables', 'computer', 'understand', 'human', 'language', '.']

# %% [markdown]
# Step 9: Part-of-Speech (POS) Tagging

# %%
pos_tags = nltk.pos_tag(words)
print(pos_tags)
# Out:
# [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('enables', 'VBZ'), ('computers', 'NNS'), ('to', 'TO'), ('understand', 'VB'), ('human', 'JJ'), ('language', 'NN'), ('.', '.')]

# %% [markdown]
# Step 10: Basic NLP Analysis

# %% [markdown]
# a) Word Frequency

# %%
from nltk.probability import FreqDist

freq_dist = FreqDist(words)
print(freq_dist.most_common(5))
# Out:
# [('Natural', 1), ('Language', 1), ('Processing', 1), ('enables', 1), ('computers', 1)]

# %% [markdown]
# b) Named Entity Recognition (Optional)

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')

named_entities = nltk.ne_chunk(pos_tags)
print(named_entities)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   Natural/JJ
#   Language/NNP
#   Processing/NNP
#   enables/VBZ
#   computers/NNS
#   to/TO
#   understand/VB
#   human/JJ
#   language/NN
#   ./.)

# %% [markdown]
# Step 11: Wrap Everything into a Simple Application

# %%
def text_analysis(text):
    tokens = word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    freq = FreqDist(tokens)

    return {
        "Tokens": tokens,
        "POS Tags": pos,
        "Word Frequency": freq.most_common(5)
    }

result = text_analysis(text)
print(result)
# Out:
# {'Tokens': ['Natural', 'Language', 'Processing', 'enables', 'computers', 'to', 'understand', 'human', 'language', '.'], 'POS Tags': [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('enables', 'VBZ'), ('computers', 'NNS'), ('to', 'TO'), ('understand', 'VB'), ('human', 'JJ'), ('language', 'NN'), ('.', '.')], 'Word Frequency': [('Natural', 1), ('Language', 1), ('Processing', 1), ('enables', 1), ('computers', 1)]}
